# %%
import pandas as pd

# %% [markdown]
# ## 資訊科目

# %%
df = pd.read_csv('資訊課程.csv')
df
# Out:
#          課號           課名    成績
# 0    IM1001       計算機概論Ｉ  88.0
# 1   IM1013C       初階程式設計  88.0
# 2   MA1201F  微積分python實作  99.0
# 3    IM1018       資訊管理導論  82.0
# 4   IM1023B     Java程式設計  95.0
# 5    GS4717         數位學習  92.0
# 6    IM2011      資料與檔案結構  94.0
# 7    IM2015     UNIX作業系統  85.0
# 8    IM4021   Java程式設計進階  87.0
# 9    IM2002        資料庫管理  81.0
# 10  IM3029B       網頁程式設計  90.0
# 11   IM3061       企業資料通訊  91.0
# 12   IM3069      系統分析與設計  94.0
# 13   IM5032      物聯網實務應用  89.0
# 14   IM2037          演算法  91.0
# 15  IM3028A    資訊系統發展專題Ｉ  94.0
# 16   IM3078    人工智慧與機器學習  93.0

# %%
df = df.drop('課號', axis=1)

# %%
df = df[df['成績'] >= 85]
df = df.sort_values('成績', ascending=False)

# %%
df
# Out:
#              課名    成績
# 2   微積分python實作  99.0
# 4      Java程式設計  95.0
# 6       資料與檔案結構  94.0
# 12      系統分析與設計  94.0
# 15    資訊系統發展專題Ｉ  94.0
# 16    人工智慧與機器學習  93.0
# 5          數位學習  92.0
# 11       企業資料通訊  91.0
# 14          演算法  91.0
# 10       網頁程式設計  90.0
# 13      物聯網實務應用  89.0
# 0        計算機概論Ｉ  88.0
# 1        初階程式設計  88.0
# 8    Java程式設計進階  87.0
# 7      UNIX作業系統  85.0

# %%
df.plot(kind='bar')
